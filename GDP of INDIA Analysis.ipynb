# %% [markdown]
# # Analysis of GDP of India (1960-2022)

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series
import matplotlib as mlt
import matplotlib.pyplot as plt
import math

# %%
Data=pd.read_csv('C:\\Users\\rawat\\Desktop\\india.csv')
Data
# Out:
#     Unnamed: 0 India GDP - Historical Data India GDP - Historical Data.1  \
# 0          NaN                        Year            GDP in (Billion) $
# 1          0.0                        2021                        3173.4
# 2          1.0                        2020                       2667.69
# 3          2.0                        2019                       2831.55
# 4          3.0                        2018                       2702.93
# ..         ...                         ...                           ...
# 58        57.0                        1964                         56.48
# 59        58.0                        1963                         48.42
# 60        59.0                        1962                         42.16
# 61        60.0                        1961                         39.23
# 62        61.0                        1960                         37.03
#
#    India GDP - Historical Data.2 India GDP - Historical Data.3
# ...

# %%
Data.describe()
# Out:
#        Unnamed: 0
# count   62.000000
# mean    30.500000
# std     18.041619
# min      0.000000
# 25%     15.250000
# 50%     30.500000
# 75%     45.750000
# max     61.000000

# %%
Data.columns=Data.iloc[0]
Data
# Out:
# 0    NaN  Year  GDP in (Billion) $  Per Capita in rupees  Growth %
# 0    NaN  Year  GDP in (Billion) $  Per Capita in rupees  Growth %
# 1    0.0  2021              3173.4                182160      8.95
# 2    1.0  2020             2667.69                154640      -6.6
# 3    2.0  2019             2831.55                165760      3.74
# 4    3.0  2018             2702.93                159840      6.45
# ..   ...   ...                 ...                   ...       ...
# 58  57.0  1964               56.48                  9280      7.45
# 59  58.0  1963               48.42                  8080      5.99
# 60  59.0  1962               42.16                  7200      2.93
# 61  60.0  1961               39.23                  6800      3.72
# 62  61.0  1960               37.03                  6560         0
#
# [63 rows x 5 columns]

# %%
data1=Data.iloc[:,1:]
data1
# Out:
# 0   Year  GDP in (Billion) $  Per Capita in rupees  Growth %
# 0   Year  GDP in (Billion) $  Per Capita in rupees  Growth %
# 1   2021              3173.4                182160      8.95
# 2   2020             2667.69                154640      -6.6
# 3   2019             2831.55                165760      3.74
# 4   2018             2702.93                159840      6.45
# ..   ...                 ...                   ...       ...
# 58  1964               56.48                  9280      7.45
# 59  1963               48.42                  8080      5.99
# 60  1962               42.16                  7200      2.93
# 61  1961               39.23                  6800      3.72
# 62  1960               37.03                  6560         0
#
# [63 rows x 4 columns]

# %%
Data2=data1.drop(0)
Data2
# Out:
# 0   Year GDP in (Billion) $ Per Capita in rupees Growth %
# 1   2021             3173.4               182160     8.95
# 2   2020            2667.69               154640     -6.6
# 3   2019            2831.55               165760     3.74
# 4   2018            2702.93               159840     6.45
# 5   2017            2651.47               158480      6.8
# ..   ...                ...                  ...      ...
# 58  1964              56.48                 9280     7.45
# 59  1963              48.42                 8080     5.99
# 60  1962              42.16                 7200     2.93
# 61  1961              39.23                 6800     3.72
# 62  1960              37.03                 6560        0
#
# [62 rows x 4 columns]

# %%
Data2.columns=['Year','GDP','GDP_per_capita','groth_per']

# %%
Data2
# Out:
#     Year      GDP GDP_per_capita groth_per
# 1   2021   3173.4         182160      8.95
# 2   2020  2667.69         154640      -6.6
# 3   2019  2831.55         165760      3.74
# 4   2018  2702.93         159840      6.45
# 5   2017  2651.47         158480       6.8
# ..   ...      ...            ...       ...
# 58  1964    56.48           9280      7.45
# 59  1963    48.42           8080      5.99
# 60  1962    42.16           7200      2.93
# 61  1961    39.23           6800      3.72
# 62  1960    37.03           6560         0
#
# [62 rows x 4 columns]

# %%
Data3=Data2.sort_values(by='Year')

# %%
Data3.index=np.arange(62)

# %%
Data3
# Out:
#     Year      GDP GDP_per_capita groth_per
# 0   1960    37.03           6560         0
# 1   1961    39.23           6800      3.72
# 2   1962    42.16           7200      2.93
# 3   1963    48.42           8080      5.99
# 4   1964    56.48           9280      7.45
# ..   ...      ...            ...       ...
# 57  2017  2651.47         158480       6.8
# 58  2018  2702.93         159840      6.45
# 59  2019  2831.55         165760      3.74
# 60  2020  2667.69         154640      -6.6
# 61  2021   3173.4         182160      8.95
#
# [62 rows x 4 columns]

# %%
# %matplotlib inline

# %%
Data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 0 to 61
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            62 non-null     object
#  1   GDP             62 non-null     object
#  2   GDP_per_capita  62 non-null     object
#  3   groth_per       62 non-null     object
# dtypes: object(4)
# memory usage: 2.4+ KB

# %%
Data3['GDP']=Data3['GDP'].astype(float)
Data3['Year']=Data3['Year'].astype(float)
Data3['GDP_per_capita']=Data3['GDP_per_capita'].astype(float)
Data3['groth_per']=Data3['groth_per'].astype(float)

# %%
Data3['GDP']=Data3['GDP'].astype(int)
Data3['Year']=Data3['Year'].astype(int)
Data3['GDP_per_capita']=Data3['GDP_per_capita'].astype(int)
Data3['groth_per']=Data3['groth_per'].astype(int)
Data3.info()
Data3.set_index('Year')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 0 to 61
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            62 non-null     int32
#  1   GDP             62 non-null     int32
#  2   GDP_per_capita  62 non-null     int32
#  3   groth_per       62 non-null     int32
# dtypes: int32(4)
# memory usage: 1.5 KB
#        GDP  GDP_per_capita  groth_per
# Year
# 1960    37            6560          0
# 1961    39            6800          3
# 1962    42            7200          2
# 1963    48            8080          5
# 1964    56            9280          7
# ...    ...             ...        ...
# 2017  2651          158480          6
# 2018  2702          159840          6
# 2019  2831          165760          3
# 2020  2667          154640         -6
# 2021  3173          182160          8
#
# [62 rows x 3 columns]

# %%
year_arr=np.arange(1960,2022)

# %%
f=plt.figure(figsize=(15,5))
plt.plot(Data3['Year'],Data3['GDP'],marker=".",mec="r")
plt.xticks(np.arange(1960,2022,3))
plt.title('GDP')
# Out:
# Text(0.5, 1.0, 'GDP')

# %%
f=plt.figure(figsize=(15,5))
plt.bar(Data3['Year'],Data3['GDP'])
plt.xticks(np.arange(1960,2022,3))
plt.title('GDP Growth Every Year')
plt.ylabel('Billions')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
year=np.arange(1960,2022)

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.plot(year,Data3['GDP_per_capita'],marker='.')
plt.xticks(np.arange(1960,2022,3))
plt.xlabel('Year')
plt.ylabel('Thousand')
plt.title('Per_Capita Growth')
# Out:
# Text(0.5, 1.0, 'Per_Capita Growth')

# %%
color=['green']*62#Create a list for color
f = plt.figure() # Create a figure 
f.set_figwidth(15)
f.set_figheight(5)
gyear=np.array(Data3['Year']).astype('S')
growth=np.array(Data3['groth_per'])
color=np.where(Data3['groth_per']>=0,'green','red')
plt.bar(year,Data3['groth_per'],color=color)
plt.xticks(np.arange(1960,2022,3))
plt.xlabel('Year')
plt.ylabel('Thousand')
plt.title('Growth %')
for x, y in zip(Data3['Year'], Data3['groth_per']):# func to add Data lables
    plt.text(x, y/2, y, ha='center', va='top', fontsize=11, color='white')

# %%
ax=plt.figure(figsize=(10,5))
plt.plot(Data3['GDP'],label='GDP')
plt.plot(Data3['GDP_per_capita'],label='Per Capita')
plt.plot(Data3['groth_per'],label='groth')
plt.legend(loc='upper left')

# %%
Data3

# %%
a=Data3['GDP']

# %%
def percentage(data):
    growth=[]
    for x in range(0,len(data)-1):
        growth.append(((data[x+1]-data[x])/data[x])*100)
    grow=[math.ceil(x) for x in growth]
    grow.insert(0,0)
    return grow

# %%
gdp_per=percentage(Data3['GDP'])
Data3['per_gdp']=gdp_per
Data3

# %%
capita_per=percentage(Data3['GDP_per_capita'])
Data3['per_growth']=capita_per
Data3.drop('groth_per',axis=1)

# %%
ax=plt.figure(figsize=(10,5))
plt.plot(Data3['Year'],Data3['GDP_per_capita'],label='GDP growth percent')
plt.plot(Data3['Year'],Data3['groth_per'],label='PER CAPITA growth percent')
plt.legend(loc='upper left')
plt.title('DIFF BETWEEN GDP AND PER CAPITA GROWTH')
# Out:
# Text(0.5, 1.0, 'DIFF BETWEEN GDP AND PER CAPITA GROWTH')

# %%
Data3
# Out:
#     Year   GDP  GDP_per_capita  groth_per
# 0   1960    37            6560          0
# 1   1961    39            6800          3
# 2   1962    42            7200          2
# 3   1963    48            8080          5
# 4   1964    56            9280          7
# ..   ...   ...             ...        ...
# 57  2017  2651          158480          6
# 58  2018  2702          159840          6
# 59  2019  2831          165760          3
# 60  2020  2667          154640         -6
# 61  2021  3173          182160          8
#
# [62 rows x 4 columns]
